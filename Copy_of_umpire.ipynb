# %% [markdown]
# <a href="https://colab.research.google.com/github/DipenB729/ExpenseTracker/blob/main/Copy_of_umpire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed May 21 03:32:55 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 99.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install ultralytics  # Install if not already done

from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# !yolo checks  # Corrected CLI usage
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.3/112.6 GB disk)
#
# OS                  Linux-6.1.123+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.11.12
# Install             pip
# Path                /usr/local/lib/python3.11/dist-packages/ultralytics
# RAM                 12.67 GB
# Disk                41.3/112.6 GB
# CPU                 Intel Xeon 2.00GHz
# CPU count           2
# GPU                 Tesla T4, 15095MiB
# GPU count           1
# CUDA                12.4
#
# numpy               ✅ 2.0.2>=1.23.0
# matplotlib          ✅ 3.10.0>=3.3.0
# opencv-python       ✅ 4.11.0.86>=4.6.0
# pillow              ✅ 11.2.1>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.15.3>=1.4.1
# torch               ✅ 2.6.0+cu124>=1.8.0
# torch               ✅ 2.6.0+cu124!=2.4.0,>=1.8.0; sys_platform == "win32"
# ...

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="uCmaqatloixJ7huVJu5V")
project = rf.workspace("umpire").project("umpire_gestures-6brud")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Umpire_Gestures-1 in yolov8:: 100%|██████████| 940/940 [00:00<00:00, 8787.76it/s]

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=20 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:01<00:00, 47.1MB/s]
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image

# Show the confusion matrix image
Image(filename='/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
from IPython.display import Image

# Show the confusion matrix image
Image(filename='/content/runs/detect/train/results.png', width=600)

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=20 imgsz=640
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1091.3±468.7 MB/s, size: 33.4 KB)
# val: Scanning /content/Umpire_Gestures-1/valid/labels.cache... 61 images, 0 backgrounds, 0 corrupt: 100% 61/61 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:02<00:00,  1.57it/s]
#                    all         61         61      0.888      0.825      0.919      0.919
#              No_Action         11         11      0.838      0.474      0.874      0.874
#                No_Ball         14         14      0.964      0.929      0.986      0.986
#                    Out         12         12      0.813      0.833      0.796      0.796
#                    Six         15         15       0.93          1      0.979      0.979
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source={dataset.location}/test/images
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/32 /content/Umpire_Gestures-1/test/images/no_action_10_jpg.rf.0c9b69fa036920294dfa3a84a24bd8eb.jpg: 640x640 1 Out, 37.1ms
# image 2/32 /content/Umpire_Gestures-1/test/images/no_action_60_jpg.rf.ebb0acb72930066ba181947add7b19c8.jpg: 640x640 1 No_Action, 37.0ms
# image 3/32 /content/Umpire_Gestures-1/test/images/no_action_6_jpg.rf.94bee28795076a3732871c5f3b26e1ec.jpg: 640x640 1 Out, 36.9ms
# image 4/32 /content/Umpire_Gestures-1/test/images/no_action_75_jpg.rf.00c003a426e35612487a5ede2e5aa553.jpg: 640x640 1 Out, 36.9ms
# image 5/32 /content/Umpire_Gestures-1/test/images/no_ball_21_jpg.rf.ec50ab378fea1575274db1220b82efc9.jpg: 640x640 1 No_Ball, 36.9ms
# image 6/32 /content/Umpire_Gestures-1/test/images/no_ball_25_jpg.rf.2e3275c6f422ccd236f0d8e870657705.jpg: 640x640 1 No_Ball, 37.0ms
# ...

# %%
import glob
from IPython.display import Image, display

# Use glob.glob() to get a list of image paths
for image_path in glob.glob('/content/runs/detect/predict/*.jpg'):
    display(Image(filename=image_path, height=600))
    print("\n")
